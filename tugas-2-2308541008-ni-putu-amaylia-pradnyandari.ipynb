# %%
angka1_08 = float(input("Masukkan angka pertama: "))
angka2_08 = float(input("Masukkan angka kedua: "))
hasil = kalikan(angka1, angka2)
print("Hasil perkalian dari" ,angka1, "dan" ,angka2, "adalah:" ,hasil)
# Out:
# Masukkan angka pertama:  1.2
# Masukkan angka kedua:  1.2
# Hasil perkalian dari 1.2 dan 1.2 adalah: 1.44

# %%
nama08 = "Amaylia"
pekerjaan = "mahasiswa"
institusi ="Universitas Udayana"
print(nama08 + " adalah seorang " + pekerjaan + " di " + institusi + '.')
# Out:
# Amaylia adalah seorang mahasiswa di Universitas Udayana.

# %%
kelas08 = "aku suka kamu tapi bohong"
print(kelas[0:-11])
# Out:
# aku suka kamu

# %%
judul = "surga itu kamu"
judul.upper()
# Out:
# 'SURGA ITU KAMU'

# %%
angka = int(input("Masukkan sebuah angka: "))
jenis_angka = ["genap", "ganjil"]
print("Angka yang dimasukkan adalah", jenis_angka[angka % 2])
# Out:
# Masukkan sebuah angka:  1
# Angka yang dimasukkan adalah ganjil

# %%
angka1 = float (input("Masukkan angka pertama: "))
angka2 = float (input("Masukkan angka kedua: "))
hasil = angka1 + angka2
x = hasil >=0
print("Hasil penjumlahan dari", angka1, "dan", angka2, "adalah:", hasil, "dimana", x)
# Out:
# Masukkan angka pertama:  1.2
# Masukkan angka kedua:  1.2
# Hasil penjumlahan dari 1.2 dan 1.2 adalah: 2.4 dimana True

# %%
tinggi_amay08 = 169
tinggi_kharin = 164
print(tinggi_amay08 < 170 and tinggi_kharin > 160)
# Out:
# True
