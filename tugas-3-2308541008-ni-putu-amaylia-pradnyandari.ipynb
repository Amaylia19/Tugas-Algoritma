# %%
zodiak_08 = input("Zodiak anda adalah")
if zodiak == "aries" :
    print("Anda lahir antara 21 Maret-19 April")
    print("Anda cocok dengan zodiak leo, sagitarius")
if zodiak == "taurus" :
    print("Anda lahir antara 20 april-20 mei")
    print("Anda cocok dengan zodiak virgo, capricorn")
if zodiak == "gemini" :
    print("Anda lahir antara 21 mei-20 juni")
    print("Anda cocok dengan zodiak libra, aquarius")  
if zodiak == "cancer" :
    print("Anda lahir antara 21 juni-22 juli")
    print("Anda cocok dengan zodiak scorpio, pisces")
if zodiak == "leo" :
    print("Anda lahir antara 23 juli-22 agustus")
    print("Anda cocok dengan zodiak aries, sagitarius")
if zodiak == "virgo" :
    print("Anda lahir antara 23 agustus-22 september")
    print("Anda cocok dengan zodiak taurus, capricon")
if zodiak == "libra" :
    print("Anda lahir antara 23 september-22 oktober")
    print("Anda cocok dengan zodiak gemini, aquarius")
if zodiak == "scorpio" :
    print("Anda lahir antara 23 oktober-21 november")
    print("Anda cocok dengan zodiak cancer, pisces")
if zodiak == "sagitarius" :
    print("Anda lahir antara 22 november-21 desember")
    print("Anda cocok dengan zodiak aries, leo")
if zodiak == "capricorn" :
    print("Anda lahir antara 22 desember-19 januari")
    print("Anda cocok dengan zodiak taurus, virgo")
if zodiak == "aquarius" :
    print("Anda lahir antara 20 januari-18 februari")
    print("Anda cocok dengan zodiak gemini, libra")
if zodiak == "pisces" :
    print("Anda lahir antara 19 februari-20 maret")
    print("Anda cocok dengan zodiak cancer, scorpio")
# Out:
# Zodiak anda adalah taurus
# Anda lahir antara 20 april-20 mei
# Anda cocok dengan zodiak virgo, capricorn

# %%
a = 0
while a < 7:
    print(a * "*")
    a += 1
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
ukuran_08 = 5
baris = 0
while baris < ukuran:
    kolom = 0
    while kolom < ukuran:
        if kolom == 0 or baris == 0 or baris == ukuran - 1 or baris == ukuran // 2:
            print("❤️", end=" ")
        else:
            print(" ", end=" ")
        kolom += 2
    print()
    baris += 1
# Out:
# ❤️ ❤️ ❤️
# ❤️
# ❤️ ❤️ ❤️
# ❤️
# ❤️ ❤️ ❤️
