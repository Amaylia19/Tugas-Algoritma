# %%
udayana = ['FMIPA','FT','FEB','FIB']
udayana.append('FISIP')
print(udayana)
# Out:
# ['FMIPA', 'FT', 'FEB', 'FIB', 'FISIP']

# %%
udayana.insert(3,'FPAR')
print(udayana)
# Out:
# ['FMIPA', 'FT', 'FEB', 'FPAR', 'FIB', 'FISIP']

# %%
udayana.remove('FPAR')
print(udayana)
# Out:
# ['FMIPA', 'FT', 'FEB', 'FIB', 'FISIP']

# %%
print ('FPAR' in udayana)
# Out:
# False

# %%
print ('FIB' in udayana)
# Out:
# True

# %%
print(len(udayana))
# Out:
# 5

# %%
for fakultas in udayana:
    print(fakultas)
# Out:
# FMIPA
# FT
# FEB
# FIB
# FISIP

# %%
i = 0
while i < len(udayana):
    print(udayana[i])
    i+=1
# Out:
# FMIPA
# FT
# FEB
# FIB
# FISIP
