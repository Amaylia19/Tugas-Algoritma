# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
###### import numpy as np

baris_08 = int(input("Masukkan jumlah baris_08: "))
kolom_08 = int(input("Masukkan jumlah kolom_08: "))

print("Masukkan elemen matriks:")
matriks_08 = []
for i in range(baris_08):
    row_08 = []
    for j in range(kolom_08):
        elemen_08 = int(input(f"Masukkan elemen baris_08 {i+1}, kolom_08 {j+1}: "))
        row_08.append(elemen_08)
    matriks_08.append(row_08) 
    
print("Matriks yang dimasukkan:")
for row_08 in matriks_08:
    print(row_08)

matriks_np_08 = np.array(matriks)

if np.linalg.matrix_rank(matriks_np_08) < min(baris_08, kolom_08):
    print("Matriks tersebut adalah matriks singular.")
    print("Nim : 2308541008")
else:
    print("Matriks tersebut bukan matriks singular.")
    print("Nim : 2308541008")
# Out:
# Masukkan jumlah baris_08:  2
# Masukkan jumlah kolom_08:  2
# Masukkan elemen matriks:
# Masukkan elemen baris_08 1, kolom_08 1:  1
# Masukkan elemen baris_08 1, kolom_08 2:  2
# Masukkan elemen baris_08 2, kolom_08 1:  3
# Masukkan elemen baris_08 2, kolom_08 2:  4
# Matriks yang dimasukkan:
# [1, 2]
# [3, 4]
# Matriks tersebut adalah matriks singular.
# Nim : 2308541008
